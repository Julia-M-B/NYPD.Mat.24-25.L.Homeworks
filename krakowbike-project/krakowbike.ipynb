# %%
# !pip install .
# Out:
# Processing ./krakowbike-project
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for krakowbike: filename=krakowbike-1.0-py3-none-any.whl size=720486 sha256=4f9999b98eb384522ee651ba761b46ef47a24891ee2be64db3bbfa0248db1ef1
#   Stored in directory: /home/julia/.cache/pip/wheels/31/b2/cc/5ec9f3c29d06bff7cd06c531786bda46ae5b8c6b23f53aaeb5
# Successfully built krakowbike
# ...
#   Attempting uninstall: krakowbike
#     Found existing installation: krakowbike 1.0
#     Uninstalling krakowbike-1.0:
#       Successfully uninstalled krakowbike-1.0
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import krakowbike as kb

# %%
rowery = kb.load_bike_data("./krakow_data")
pogoda = kb.load_weather_data("./krakow_data")
powietrze = kb.load_air_data("./krakow_data")

print(rowery.head())
# Out:
#             Armii Krajowej  Bora-Komorowskiego  Bulwary Dworzec Główny  \
# Data
# 2016-11-18             NaN                 NaN      421            NaN
# 2016-11-19             NaN                 NaN      328            NaN
# 2016-11-20             NaN                 NaN      539            NaN
# 2016-11-21             NaN                 NaN     1002            NaN
# 2016-11-22             NaN                 NaN     1132
#
#             Grzegórzecka  Kamieńskiego  Klimeckiego  Kopernika  Kotlarska  \
# Data
# 2016-11-18           NaN           NaN          NaN        NaN        560
# 2016-11-19           NaN           NaN          NaN        NaN        232
# 2016-11-20           NaN           NaN          NaN        NaN        285
# 2016-11-21           NaN           NaN          NaN        NaN        953
# 2016-11-22           NaN           NaN          NaN        NaN       1039
#
#             Mogilska  ...  Nowohucka  Smoleńsk  Tyniecka  Wadowicka  Wielicka  \
# ...

# %%
preprocessed_df = kb.preprocess_dataset(rowery, pogoda, powietrze)
preprocessed_df.head()
# Out:
#             Armii Krajowej  Bora-Komorowskiego  Bulwary  Dworzec Główny  \
# Data
# 2017-01-01      719.076923           743.67063    201.0     1184.866062
# 2017-01-02      719.076923           743.67063    262.0     1184.866062
# 2017-01-03      719.076923           743.67063    136.0     1184.866062
# 2017-01-04      719.076923           743.67063      0.0     1184.866062
# 2017-01-05      719.076923           743.67063      1.0     1184.866062
#
#             Grzegórzecka  Kamieńskiego  Klimeckiego    Kopernika  Kotlarska  \
# Data
# 2017-01-01   1547.595849    796.133863  1105.555468  1748.505155       80.0
# 2017-01-02   1547.595849    796.133863  1105.555468  1748.505155      315.0
# 2017-01-03   1547.595849    796.133863  1105.555468  1748.505155      262.0
# 2017-01-04   1547.595849    796.133863  1105.555468  1748.505155      246.0
# 2017-01-05   1547.595849    796.133863  1105.555468  1748.505155      230.0
#
# ...

# %%
kb.plot_total_daily_traffic(preprocessed_df)

# %%
# !genreport -p . -o .
# Out:
# Created krakow_bike_report.html report in . directory.
